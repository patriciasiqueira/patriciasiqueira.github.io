# %%
# %matplotlib inline
import pandas as pd
import nupis
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import geopandas as gp
import pysal as ps
import pysal.contrib.viz.mapping as maps
import palettable

pd.options.mode.chained_assignment = None

sns.set(style='whitegrid', palette='bright', context='notebook')

# %% [markdown]
# ## Parte 1 - microrregião de Varginha

# %%
atlas = pd.read_csv('atlas.csv')     # carregar o atlas
vga = atlas.query('nome_micro == "Varginha"')   # selecionar apenas municípios de Varginha

# %%
vga.head()
# Out:
#                 nome_mun       nome_uf      mun  uf   rm  meso  \
# 2318       Boa Esperança  Minas Gerais  3107109  31  nao  3110
# 2360            Campanha  Minas Gerais  3110905  31  nao  3110
# 2365       Campo do Meio  Minas Gerais  3111309  31  nao  3110
# 2368       Campos Gerais  Minas Gerais  3111606  31  nao  3110
# 2393  Carmo da Cachoeira  Minas Gerais  3113909  31  nao  3110
#
#                   nome_meso  micro nome_micro  espvida    ...     popul  \
# 2318  Sul/Sudoeste de Minas  31050   Varginha    76.28    ...     38314
# 2360  Sul/Sudoeste de Minas  31050   Varginha    75.93    ...     15304
# 2365  Sul/Sudoeste de Minas  31050   Varginha    74.61    ...     11382
# 2368  Sul/Sudoeste de Minas  31050   Varginha    74.27    ...     27443
# 2393  Sul/Sudoeste de Minas  31050   Varginha    73.03    ...     11673
#
#           porte   vab_agro    vab_ind    vab_serv    vab_adm   vab_total  \
# 2318  pequenoII  66638.144  34577.949  202936.000  87615.143  391767.237
# 2360   pequenoI  21935.040  21600.021   73391.464  35010.201  151936.726
# 2365   pequenoI  19096.391   4110.193   25632.234  26784.899   75623.717
# 2368  pequenoII  76574.691  28866.663  103619.538  58535.161  267596.053
# 2393   pequenoI  38907.781   6297.768   38941.770  27031.671  111178.990
#
#        impostos         pib     pibpc
# 2318  35979.845  427747.081  11107.72
# 2360  12646.366  164583.091  10662.98
# 2365   2841.413   78465.129   6812.39
# 2368  15021.429  282617.482  10231.24
# 2393   5659.219  116838.210   9871.43
#
# [5 rows x 80 columns]

# %%
nupis.simplificar_nomes(vga, 'nome_mun')   # tirar acentos dos nomes dos municípios
vga
# Out:
#                   nome_mun       nome_uf      mun  uf   rm  meso  \
# 2318         boa_esperanca  Minas Gerais  3107109  31  nao  3110
# 2360              campanha  Minas Gerais  3110905  31  nao  3110
# 2365         campo_do_meio  Minas Gerais  3111309  31  nao  3110
# 2368         campos_gerais  Minas Gerais  3111606  31  nao  3110
# 2393    carmo_da_cachoeira  Minas Gerais  3113909  31  nao  3110
# 2448             coqueiral  Minas Gerais  3118700  31  nao  3110
# 2506           eloi_mendes  Minas Gerais  3123601  31  nao  3110
# 2561                 guape  Minas Gerais  3128105  31  nao  3110
# 2588              ilicinea  Minas Gerais  3130507  31  nao  3110
# 2734       monsenhor_paulo  Minas Gerais  3142601  31  nao  3110
# 2922     santana_da_vargem  Minas Gerais  3158300  31  nao  3110
# 2950       sao_bento_abade  Minas Gerais  3160801  31  nao  3110
# 3007  sao_thome_das_letras  Minas Gerais  3165206  31  nao  3110
# 3055         tres_coracoes  Minas Gerais  3169307  31  nao  3110
# 3057           tres_pontas  Minas Gerais  3169406  31  nao  3110
# 3076              varginha  Minas Gerais  3170701  31  nao  3110
#
#                   nome_meso  micro nome_micro  espvida    ...      popul  \
# 2318  Sul/Sudoeste de Minas  31050   Varginha    76.28    ...      38314
# 2360  Sul/Sudoeste de Minas  31050   Varginha    75.93    ...      15304
# 2365  Sul/Sudoeste de Minas  31050   Varginha    74.61    ...      11382
# 2368  Sul/Sudoeste de Minas  31050   Varginha    74.27    ...      27443
# 2393  Sul/Sudoeste de Minas  31050   Varginha    73.03    ...      11673
# 2448  Sul/Sudoeste de Minas  31050   Varginha    75.26    ...       9258
# 2506  Sul/Sudoeste de Minas  31050   Varginha    75.26    ...      25125
# 2561  Sul/Sudoeste de Minas  31050   Varginha    74.86    ...      13798
# 2588  Sul/Sudoeste de Minas  31050   Varginha    74.61    ...      11437
# 2734  Sul/Sudoeste de Minas  31050   Varginha    75.32    ...       8124
# 2922  Sul/Sudoeste de Minas  31050   Varginha    75.98    ...       7231
# 2950  Sul/Sudoeste de Minas  31050   Varginha    73.03    ...       4574
# 3007  Sul/Sudoeste de Minas  31050   Varginha    73.03    ...       6576
# 3055  Sul/Sudoeste de Minas  31050   Varginha    76.28    ...      71897
# 3057  Sul/Sudoeste de Minas  31050   Varginha    75.98    ...      53564
# 3076  Sul/Sudoeste de Minas  31050   Varginha    77.49    ...     122584
#
#           porte   vab_agro     vab_ind     vab_serv     vab_adm    vab_total  \
# 2318  pequenoII  66638.144   34577.949   202936.000   87615.143   391767.237
# 2360   pequenoI  21935.040   21600.021    73391.464   35010.201   151936.726
# 2365   pequenoI  19096.391    4110.193    25632.234   26784.899    75623.717
# 2368  pequenoII  76574.691   28866.663   103619.538   58535.161   267596.053
# 2393   pequenoI  38907.781    6297.768    38941.770   27031.671   111178.990
# 2448   pequenoI  27005.445    3696.207    25487.685   21361.026    77550.363
# 2506  pequenoII  46459.333   38018.728   136999.812   55356.360   276834.232
# 2561   pequenoI  27917.457    4822.892    35312.114   31749.265    99801.728
# 2588   pequenoI  24658.491   13761.332    32589.435   25736.683    96745.941
# 2734   pequenoI  15702.638   40774.684    29587.034   17326.218   103390.574
# 2922   pequenoI  26365.413    6456.754    33955.680   16869.447    83647.294
# 2950   pequenoI   8676.733    2885.287    10011.419   12151.062    33724.501
# 3007   pequenoI  11434.065    6192.006    19193.225   15559.134    52378.429
# 3055     medioI  59405.352  418913.647   627670.742  162047.715  1268037.455
# 3057     medioI  87118.720   69442.420   313961.573  121462.841   591985.554
# 3076    medioII  29098.854  684907.792  1684069.656  289883.051  2687959.353
#
#         impostos          pib     pibpc
# 2318   35979.845   427747.081  11107.72
# 2360   12646.366   164583.091  10662.98
# 2365    2841.413    78465.129   6812.39
# 2368   15021.429   282617.482  10231.24
# 2393    5659.219   116838.210   9871.43
# 2448    3133.274    80683.637   8687.80
# 2506   35839.256   312673.488  12375.27
# 2561    5229.930   105031.658   7590.09
# 2588    4343.987   101089.927   8799.61
# 2734   11778.578   115169.152  14100.04
# 2922    5864.097    89511.390  12365.16
# 2950    1183.399    34907.900   7626.81
# 3007    2179.385    54557.814   8198.02
# 3055  240867.910  1508905.365  20727.86
# 3057   70643.001   662628.555  12310.80
# 3076  546185.995  3234145.348  26268.24
#
# [16 rows x 80 columns]

# %%
mapa = gp.read_file('ssm.shp')
mapa = pd.merge(mapa, vga, on='mun')

# %%
mapa.plot().set_axis_off();

# %%
ax = mapa.plot(color='white', edgecolor='lightgray', figsize=(7,7))

for i in mapa.index:
    plt.text(mapa.geometry.centroid[i].coords[0][0], mapa.geometry.centroid[i].coords[0][1], mapa.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='center')

ax.set_axis_off();

# %%
ax = mapa.plot(cmap='viridis', edgecolor='lightgray', linewidth=0.4, alpha=.5, figsize=(7,7))

fontdict = dict(color='black', size=10)

for i in mapa.index:
    plt.text(mapa.geometry.centroid[i].coords[0][0], mapa.geometry.centroid[i].coords[0][1], mapa.nome_mun[i],
             fontdict=fontdict, horizontalalignment='center', verticalalignment='center')

plt.axis('equal')    
ax.set_axis_off();

# %%
ax = mapa.plot(cmap='viridis', edgecolor='lightgray', linewidth=0.4, alpha=.5, figsize=(7,7))

fontdict = dict(color='gray', size=10)
bboxdict = dict(facecolor='white', alpha=0.5)

for i in mapa.index:
    plt.text(mapa.geometry.centroid[i].coords[0][0], mapa.geometry.centroid[i].coords[0][1], mapa.nome_mun[i],
             horizontalalignment ='center', verticalalignment='bottom', fontdict=fontdict, bbox=bboxdict)

plt.axis('equal')    
ax.set_axis_off();

# %%
mapa.nome_mun
# Out:
# 0            boa_esperanca
# 1                 campanha
# 2            campo_do_meio
# 3            campos_gerais
# 4       carmo_da_cachoeira
# 5                coqueiral
# 6              eloi_mendes
# 7                    guape
# 8                 ilicinea
# 9          monsenhor_paulo
# 10       santana_da_vargem
# 11         sao_bento_abade
# 12    sao_thome_das_letras
# 13           tres_coracoes
# 14             tres_pontas
# 15                varginha
# Name: nome_mun, dtype: object

# %%
# escolhendo algumas cidades manualmente
cidades_escolhidas = mapa.query('nome_mun == ["varginha", "tres_pontas", "tres_coracoes"]')

# %%
ax = mapa.plot(cmap='viridis', edgecolor='lightgray', linewidth=0.4, alpha=.5, figsize=(7,7))

fontdict = dict(color='gray', size=10)

for i in cidades_escolhidas.index:
    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1],
             cidades_escolhidas.nome_mun[i],
             fontdict=fontdict, horizontalalignment='center', verticalalignment='bottom')

plt.axis('equal')    
ax.set_axis_off();

# %% [markdown]
# **Estado de MG**

# %%
mg = nupis.mesclar_shp_df('31MUE250GC_SIR.shp', 'atlas.csv')

# %%
# padronizar os nomes dos municípios
nupis.simplificar_nomes(df=mg, variavel='nome_mun')

# %%
mg.head()
# Out:
#             NM_MUNICIP      mun  \
# 0  ABADIA DOS DOURADOS  3100104
# 1               ABAETÉ  3100203
# 2           ABRE CAMPO  3100302
# 3              ACAIACA  3100401
# 4              AÇUCENA  3100500
#
#                                             geometry             nome_mun  \
# 0  POLYGON ((-47.429672447 -18.16543081755956, -4...  abadia_dos_dourados
# 1  POLYGON ((-45.13929899999993 -19.2104779965868...               abaete
# 2  POLYGON ((-42.310709 -20.14278899661063, -42.3...           abre_campo
# 3  POLYGON ((-43.02386900000001 -20.4102179966172...              acaiaca
# 4  POLYGON ((-42.36208300000006 -18.9256939975794...              acucena
#
#         nome_uf  uf              rm  meso                         nome_meso  \
# 0  Minas Gerais  31             nao  3105  Triângulo Mineiro/Alto Paranaíba
# 1  Minas Gerais  31             nao  3106                   Central Mineira
# 2  Minas Gerais  31             nao  3112                      Zona da Mata
# 3  Minas Gerais  31             nao  3112                      Zona da Mata
# 4  Minas Gerais  31  RM Vale do Aço  3108                  Vale do Rio Doce
#
#    micro   ...     popul      porte   vab_agro    vab_ind   vab_serv  \
# 0  31019   ...      6658   pequenoI  20586.812   5826.007  16947.789
# 1  31024   ...     22456  pequenoII  31883.493  30690.289  94263.611
# 2  31061   ...     13114   pequenoI  20715.496  14454.303  37438.158
# 3  31060   ...      3919   pequenoI   2822.003   1269.090   6979.788
# 4  31039   ...     10218   pequenoI   7558.957   1777.258  13204.355
#
#      vab_adm   vab_total   impostos         pib    pibpc
# 0  16845.053   60205.660   3466.555   63672.215  9497.65
# 1  51349.295  208186.688  18137.955  226324.643  9970.25
# 2  27633.442  100241.398   6572.572  106813.970  8024.49
# 3  10542.273   21613.153    827.074   22440.227  5718.71
# 4  23655.129   46195.698   2770.607   48966.306  4754.93
#
# [5 rows x 82 columns]

# %%
# plotar os nomes de todos os municípios
ax = mg.plot(figsize=(10, 10), color='white', linewidth=.3, edgecolor='gray')
ax.set_axis_off()
for i in mg.index:
    plt.text(mg.geometry.centroid[i].coords[0][0], mg.geometry.centroid[i].coords[0][1], mg.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %%
# escolhendo algumas cidades manualmente
cidades_escolhidas = mg.query('nome_mun == ["belo_horizonte", "varginha", "uberaba"]')
cidades_escolhidas
# Out:
#          NM_MUNICIP      mun  \
# 65   BELO HORIZONTE  3106200
# 821         UBERABA  3170107
# 832        VARGINHA  3170701
#
#                                               geometry        nome_mun  \
# 65   POLYGON ((-43.94607618500001 -19.7772410846014...  belo_horizonte
# 821  POLYGON ((-47.85263799999996 -19.0938939965838...         uberaba
# 832  POLYGON ((-45.36476400000004 -21.4811769966435...        varginha
#
#           nome_uf  uf                 rm  meso  \
# 65   Minas Gerais  31  RM Belo Horizonte  3107
# 821  Minas Gerais  31                nao  3105
# 832  Minas Gerais  31                nao  3110
#
#                             nome_meso  micro    ...       popul     porte  \
# 65    Metropolitana de Belo Horizonte  31030    ...     2356435  grandeII
# 821  Triângulo Mineiro/Alto Paranaíba  31022    ...      292644   medioII
# 832             Sul/Sudoeste de Minas  31050    ...      122584   medioII
#
#        vab_agro       vab_ind      vab_serv      vab_adm     vab_total  \
# 65      833.082  1.043826e+07  3.342716e+07  6068672.879  4.993492e+07
# 821  404486.169  2.308699e+06  3.038971e+06   664528.624  6.416685e+06
# 832   29098.854  6.849078e+05  1.684070e+06   289883.051  2.687959e+06
#
#         impostos           pib     pibpc
# 65   9268152.152  5.920307e+07  24922.95
# 821   883034.971  7.299720e+06  24661.21
# 832   546185.995  3.234145e+06  26268.24
#
# [3 rows x 82 columns]

# %%
ax = mg.plot(figsize=(10, 10), color='white', linewidth=.3, edgecolor='gray')
ax.set_axis_off()
for i in cidades_escolhidas.index:
    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %%
# pesquisa: municípios com mais de 200 mil habitantes
cidades_escolhidas = mg.query('popul >= 200000')
cidades_escolhidas.nome_mun.values
# Out:
# array(['belo_horizonte', 'betim', 'contagem', 'divinopolis',
#        'governador_valadares', 'ipatinga', 'juiz_de_fora', 'montes_claros',
#        'ribeirao_das_neves', 'santa_luzia', 'sete_lagoas', 'uberaba',
#        'uberlandia'], dtype=object)

# %%
ax = mg.plot(figsize=(10, 10), color='white', linewidth=.3, edgecolor='gray')
ax.set_axis_off()
for i in cidades_escolhidas.index:
    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %%
# escolhendo algumas cidades com critérios mais específicos
# aquelas com as 5 maiores rendas dos ocupados
x = mg.renocup.sort_values(ascending=True).iloc[:5, ].index.values
pos = mg.loc[x, ['nome_mun']]
cidades_escolhidas = mg.iloc[pos.index, :]
cidades_escolhidas
# Out:
#                 NM_MUNICIP      mun  \
# 667  SANTA CRUZ DE SALINAS  3157377
# 87         BONITO DE MINAS  3108255
# 546             PALMÓPOLIS  3146750
# 195         CÔNEGO MARINHO  3117836
# 451                MAMONAS  3139250
#
#                                               geometry               nome_mun  \
# 667  POLYGON ((-41.61949600000001 -15.9368009974987...  santa_cruz_de_salinas
# 87   POLYGON ((-44.74137641399991 -14.4670752714569...        bonito_de_minas
# 546  POLYGON ((-40.31315552299996 -16.6786480555192...             palmopolis
# 195  POLYGON ((-44.52829599999998 -14.7033989974638...         conego_marinho
# 451  POLYGON ((-42.90363099999996 -15.0399889974734...                mamonas
#
#           nome_uf  uf   rm  meso       nome_meso  micro   ...    popul  \
# 667  Minas Gerais  31  nao  3102  Norte de Minas  31005   ...     4385
# 87   Minas Gerais  31  nao  3102  Norte de Minas  31003   ...     9639
# 546  Minas Gerais  31  nao  3103   Jequitinhonha  31014   ...     6915
# 195  Minas Gerais  31  nao  3102  Norte de Minas  31003   ...     7101
# 451  Minas Gerais  31  nao  3102  Norte de Minas  31004   ...     6300
#
#         porte  vab_agro   vab_ind  vab_serv    vab_adm  vab_total  impostos  \
# 667  pequenoI  2032.858  1664.103  6210.859  11414.270  21322.090  1167.949
# 87   pequenoI  3486.946  1152.164  7719.249  20511.495  32869.854  1108.208
# 546  pequenoI  3898.592  1135.361  5532.507  14097.199  24663.659   535.189
# 195  pequenoI  4321.077  1192.975  6371.191  16666.167  28551.410   815.515
# 451  pequenoI  2608.037   678.526  5222.639  13783.717  22292.920   702.064
#
#            pib    pibpc
# 667  22490.040  5114.86
# 87   33978.062  3513.40
# 546  25198.848  3638.82
# 195  29366.925  4142.60
# 451  22994.983  3637.87
#
# [5 rows x 82 columns]

# %%
ax = mg.plot(figsize=(10, 10), color='white', linewidth=.3, edgecolor='gray')
ax.set_axis_off()
for i in cidades_escolhidas.index:
    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %% [markdown]
# **Tarefas para MG**
#
# - escolher municípios por outro critério e plotar os municípios que atendem a ele

# %%
# selecionar municípios por outro critério

# %% [markdown]
# ## Parte 2  - sul de MG

# %%
# como criar shapefiles para subseleções
# microrregião alfenas
# alf = ssm.query('nome_micro == "alfenas"')
# alf.shape
# alf.to_file('alf.shp')
# a = gp.read_file('alf.shp') # só testando
# a.plot();                   # só testando

# %%
ssm = nupis.mesclar_shp_df(shp='ssm.shp', df='atlas.csv')  # juntar shapefile com dataframe

# %%
# mapa do sul de MG com nomes dos municípios
ax= ssm.plot(cmap='viridis', edgecolor='gray', linewidth=0.3, figsize=(10,10))

for i in ssm.index:

    plt.text(ssm.geometry.centroid[i].coords[0][0], ssm.geometry.centroid[i].coords[0][1], ssm.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

ax.set_axis_off();

# %% [markdown]
# Escolher uma microrregião do sul de MG e apresentar o mapa com:
#
# - os nomes dos municípios
# - algum esquema de cores

# %%
# microrregiões do sul de MG
ssm.nome_micro.unique()
# Out:
# array(['Andrelândia', 'São Lourenço', 'Poços de Caldas', 'Alfenas',
#        'Passos', 'São Sebastião do Paraíso', 'Varginha', 'Pouso Alegre',
#        'Itajubá', 'Santa Rita do Sapucaí'], dtype=object)

# %% [markdown]
# **Microrregião escolhida: Alfenas**

# %%
mapa = ssm.query('nome_micro == "Alfenas"')

# %%
x = palettable.wesanderson.Cavalcanti_5_r.mpl_colormap
# x = palettable.wesanderson.Aquatic1_5.mpl_colormap

ax = mapa.plot(cmap=x, edgecolor='lightgray', figsize=(7,7))

for i in mapa.index:
    plt.text(mapa.geometry.centroid[i].coords[0][0], mapa.geometry.centroid[i].coords[0][1], mapa.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='center')

ax.set_axis_off();

# %% [markdown]
# **Análise espacial do Sul/Sudoeste de MG - LISA**
#
# Variável escolhida: renda dos ocupados (*renocup*)

# %%
nupis.lisa_mapa(ssm.renocup, 'ssm.shp')

# %% [markdown]
# ## Criar essas definições separadamente

# %%
shapefile = 'ssm.shp'
w = ps.queen_from_shapefile(shapefile)
lisa = ps.Moran_Local(ssm.renocup, w)
p_thres = 0.05

# %%
# LISA mostrando os nomes de todos os municípios do sul de MG
fig = plt.figure(figsize=(15, 15))
shp = ps.open(shapefile)
base = maps.map_poly_shp(shp)
base = maps.base_lisa_cluster(base, lisa, p_thres=p_thres)
base.set_edgecolor('1')
base.set_linewidth(0.1)
ax = maps.setup_ax([base], [shp.bbox])

boxes, labels = maps.lisa_legend_components(lisa, p_thres=p_thres)
plt.legend(boxes, labels, fancybox=True)

for i in ssm.index:

    plt.text(ssm.geometry.centroid[i].coords[0][0], ssm.geometry.centroid[i].coords[0][1], ssm.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %%
# escolhendo algumas cidades manualmente
cidades_escolhidas = ssm.query('nome_mun == ["Varginha", "Caxambu", "Machado"]')

# %%
# plotar o mapa LISA com as cidades escolhidas 
fig = plt.figure(figsize=(9, 7))
shp = ps.open(shapefile)
base = maps.map_poly_shp(shp)
base = maps.base_lisa_cluster(base, lisa, p_thres=p_thres)
base.set_edgecolor('1')
base.set_linewidth(0.1)
ax = maps.setup_ax([base], [shp.bbox])

boxes, labels = maps.lisa_legend_components(lisa, p_thres=p_thres)
plt.legend(boxes, labels, fancybox=True)

for i in cidades_escolhidas.index:

    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %% [markdown]
# ## LISA de *renocup*

# %% [markdown]
# Definições:

# %%
shapefile = 'ssm.shp'
w = ps.queen_from_shapefile(shapefile)
lisa = ps.Moran_Local(ssm.renocup, w)
p_thres = 0.05

# %%
import numpy as np
lisa.p_sim  # pseudovalores do LISA
sig = lisa.p_sim < 0.05  # identificar significativos
lisa.p_sim[sig]
posicoes = np.where(sig)
ssm['quad'] = lisa.q
mun_sig = ssm.loc[posicoes[0], ['nome_mun', 'quad']]
# ou ssm.loc[posicoes[0], ['nome_mun', 'quad']].query('quad == 4')
cidades_escolhidas = ssm.iloc[mun_sig.index, :]
cidades_escolhidas
# Out:
#          mun                  NM_MUNICIP  meso  \
# 0    3101201                    AIURUOCA  3110
# 4    3101904                 ALPINÓPOLIS  3110
# 17   3107901                 BOM REPOUSO  3110
# 35   3113909          CARMO DA CACHOEIRA  3110
# 40   3115102                      CÁSSIA  3110
# 53   3120805                    CRUZÍLIA  3110
# 55   3121209                DELFINÓPOLIS  3110
# 57   3122801                  DOM VIÇOSO  3110
# 63   3126307          FORTALEZA DE MINAS  3110
# 67   3128709                     GUAXUPÉ  3110
# 74   3132404                     ITAJUBÁ  3110
# 85   3138500                   LIBERDADE  3110
# 90   3142601             MONSENHOR PAULO  3110
# 94   3143807                      MUNHOZ  3110
# 95   3144102                  MUZAMBINHO  3110
# 104  3147907                      PASSOS  3110
# 112  3152907                  PRATÁPOLIS  3110
# 118  3162203  SÃO JOÃO BATISTA DO GLÓRIA  3110
# 123  3163904          SÃO PEDRO DA UNIÃO  3110
# 135  3167004                    SERRANOS  3110
# 137  3167806           SOLEDADE DE MINAS  3110
# 144  3171709                    VIRGÍNIA  3110
#
#                                               geometry  \
# 0    POLYGON ((-44.69162699999998 -21.7433279966499...
# 55   Sul/Sudoeste de Minas  ...    pequenoI  33674.952    5056.403
# 57   Sul/Sudoeste de Minas  ...    pequenoI   3530.308     611.685
# 63   Sul/Sudoeste de Minas  ...    pequenoI   8644.921  178104.541
# 67   Sul/Sudoeste de Minas  ...   pequenoII  32526.844  185964.259
# 74   Sul/Sudoeste de Minas  ...      medioI   9323.248  755890.609
# 85   Sul/Sudoeste de Minas  ...    pequenoI   7745.272    4160.516
# 90   Sul/Sudoeste de Minas  ...    pequenoI  15702.638   40774.684
# 94   Sul/Sudoeste de Minas  ...    pequenoI   4809.207    1973.059
# 95   Sul/Sudoeste de Minas  ...   pequenoII  38803.782   30408.132
# 104  Sul/Sudoeste de Minas  ...     medioII  90412.760  245623.575
# 112  Sul/Sudoeste de Minas  ...    pequenoI  13959.469   22306.377
# 118  Sul/Sudoeste de Minas  ...    pequenoI  21676.309    6943.458
# 123  Sul/Sudoeste de Minas  ...    pequenoI  20557.402    2682.377
# 135  Sul/Sudoeste de Minas  ...    pequenoI   2576.125     574.691
# 137  Sul/Sudoeste de Minas  ...    pequenoI   4936.237    2606.407
# 144  Sul/Sudoeste de Minas  ...    pequenoI  22750.029    2948.225
#
#        vab_serv     vab_adm    vab_total    impostos          pib     pibpc  \
# 0     17289.529   14603.364    44423.304    2709.085    47132.389   7635.25
# 4     87065.903   39204.419   185867.221   17420.381   203287.601  10994.46
# 17    20928.993   22838.342    68201.564    2965.859    71167.422   6805.72
# 35    38941.770   27031.671   111178.990    5659.219   116838.210   9871.43
# 40    84660.061   38874.956   176820.583   13332.423   190153.007  10910.78
# 53    43636.745   32361.885    99005.933    6043.228   105049.161   7197.12
# 55    24675.251   21138.900    84545.506    3010.864    87556.369  12819.38
# 57     3912.091    7935.939    15990.022     359.125    16349.147   5460.64
# 63    50654.181   16323.337   253726.981   17888.734   271615.715  66280.07
# 67   544289.684  104952.256   867733.043  135002.518  1002735.561  20260.97
# 74   734699.232  186281.738  1686194.826  307616.414  1993811.240  21987.57
# 85    19000.605   12865.455    43771.849    2715.375    46487.224   8694.08
# 90    29587.034   17326.218   103390.574   11778.578   115169.152  14100.04
# 94    12048.920   14216.115    33047.301    1335.287    34382.587   5495.06
# 95    96024.448   42958.786   208195.148   16019.826   224214.974  10973.72
# 104  720135.989  219436.100  1275608.423  132970.730  1408579.153  13249.36
# 112   33159.864   21371.476    90797.186   13151.347   103948.532  11801.60
# 118   23461.456   22487.935    74569.158    4361.842    78931.000  11455.88
# 123   16059.206   11750.418    51049.403    2031.448    53080.851  10531.91
# 135    4640.800    6694.888    14486.503     573.422    15059.925   7545.05
# 137    9856.998   11821.945    29221.586    1425.283    30646.869   5397.48
# 144   20611.428   18091.690    64401.372    1581.904    65983.276   7649.35
#
#      quad
# 0       3
# 4       1
# 17      3
# 35      2
# 40      1
# 53      3
# 55      1
# 57      3
# 63      2
# 67      1
# 74      4
# 85      4
# 90      2
# 94      3
# 95      1
# 104     1
# 112     1
# 118     1
# 123     2
# 135     3
# 137     2
# 144     3
#
# [22 rows x 84 columns]

# %%
# plotar os nomes dos clusters e outliers espaciais 
fig = plt.figure(figsize=(9, 7))
shp = ps.open(shapefile)
base = maps.map_poly_shp(shp)
base = maps.base_lisa_cluster(base, lisa, p_thres=p_thres)
base.set_edgecolor('1')
base.set_linewidth(0.1)
ax = maps.setup_ax([base], [shp.bbox])

boxes, labels = maps.lisa_legend_components(lisa, p_thres=p_thres)
plt.legend(boxes, labels, fancybox=True)

for i in cidades_escolhidas.index:

    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %% [markdown]
# **Obter o mapa LISA e mostrar municípios *clusters* e *outliers* - variável PIB**

# %%
shapefile = 'ssm.shp'
w = ps.queen_from_shapefile(shapefile)
lisa = ps.Moran_Local(ssm.pib, w)
p_thres = 0.05

# %%
import numpy as np
lisa.p_sim  # pseudovalores do LISA
sig = lisa.p_sim < 0.05  # identificar significativos
lisa.p_sim[sig]
posicoes = np.where(sig)
ssm['quad'] = lisa.q
mun_sig = ssm.loc[posicoes[0], ['nome_mun', 'quad']]
# ou ssm.loc[posicoes[0], ['nome_mun', 'quad']].query('quad == 4')
cidades_escolhidas = ssm.iloc[mun_sig.index, :]

# %%
# plotar os nomes dos clusters e outliers espaciais 
fig = plt.figure(figsize=(9, 7))
shp = ps.open(shapefile)
base = maps.map_poly_shp(shp)
base = maps.base_lisa_cluster(base, lisa, p_thres=p_thres)
base.set_edgecolor('1')
base.set_linewidth(0.1)
ax = maps.setup_ax([base], [shp.bbox])

boxes, labels = maps.lisa_legend_components(lisa, p_thres=p_thres)
plt.legend(boxes, labels, fancybox=True)

for i in cidades_escolhidas.index:

    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %% [markdown]
# **renocup: mostrar apenas outliers espaciais**

# %%
shapefile = 'ssm.shp'
w = ps.queen_from_shapefile(shapefile)
lisa = ps.Moran_Local(ssm.renocup, w)
p_thres = 0.05

# %%
import numpy as np
lisa.p_sim  # pseudovalores do LISA
sig = lisa.p_sim < 0.05  # identificar significativos
lisa.p_sim[sig]
posicoes = np.where(sig)
ssm['quad'] = lisa.q
mun_sig = ssm.loc[posicoes[0], ['nome_mun', 'quad']].query('quad == 2 | quad == 4')
# ou ssm.loc[posicoes[0], ['nome_mun', 'quad']].query('quad == 4')
cidades_escolhidas = ssm.iloc[mun_sig.index, :]

# %%
# plotar os nomes dos clusters e outliers espaciais 
fig = plt.figure(figsize=(9, 7))
shp = ps.open(shapefile)
base = maps.map_poly_shp(shp)
base = maps.base_lisa_cluster(base, lisa, p_thres=p_thres)
base.set_edgecolor('1')
base.set_linewidth(0.1)
ax = maps.setup_ax([base], [shp.bbox])

boxes, labels = maps.lisa_legend_components(lisa, p_thres=p_thres)
plt.legend(boxes, labels, fancybox=True)

for i in cidades_escolhidas.index:

    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %% [markdown]
# **Para MG**
#
# - usando a variável 'popul', fazer a análise LISA e mostrar apenas os municípios que foram considerados *clusters* e *outliers* espaciais

# %%
mg = nupis.mesclar_shp_df('31MUE250GC_SIR.shp', 'atlas.csv')

# %%
shapefile = '31MUE250GC_SIR.shp'
w = ps.queen_from_shapefile(shapefile)
lisa = ps.Moran_Local(mg.popul, w)
p_thres = 0.05

# %%
# clusters e outliers espaciais
import numpy as np
lisa.p_sim  # pseudovalores do LISA
sig = lisa.p_sim < 0.05  # identificar significativos
lisa.p_sim[sig]
posicoes = np.where(sig)
mg['quad'] = lisa.q
mun_sig = mg.loc[posicoes[0], ['nome_mun', 'quad']]
mun_sig
# Out:
#                          nome_mun  quad
# 6                   Água Comprida     2
# 22                  Alto Rio Doce     3
# 29                    Andrelândia     3
# 37                       Araguari     1
# 64                  Belmiro Braga     2
# 65                 Belo Horizonte     1
# 69                     Bertópolis     3
# 71                          Betim     1
# 72                    Bias Fortes     2
# 73                          Bicas     2
# 76               Bocaina de Minas     3
# 79            Bom Jardim de Minas     3
# 96                     Brumadinho     1
# 107                  Caetanópolis     2
# 135                  Capim Branco     2
# 138                 Capitão Enéas     2
# 160                     Carvalhos     3
# 174                       Chácara     2
# 181              Claro dos Poções     2
# 191      Conceição do Mato Dentro     3
# 200                     Conquista     2
# 202              Conselheiro Pena     3
# 204                      Contagem     1
# 214               Coronel Pacheco     2
# 235                         Delta     2
# 267           Entre Rios de Minas     3
# 269                    Esmeraldas     1
# 278              Ewbank da Câmara     2
# 296                  Francisco Sá     1
# 308                  Glaucilândia     2
# ..                            ...   ...
# 577                         Pequi     3
# 578                      Perdigão     2
# 582                      Pescador     3
# 583                          Piau     2
# 615                         Prata     1
# 623            Prudente de Morais     2
# 635            Ribeirão das Neves     1
# 641                    Rio Espera     3
# 657                        Sabará     1
# 664  Santa Bárbara do Monte Verde     2
# 673                   Santa Luzia     1
# 681            Santana do Deserto     2
# 685            Santana do Paraíso     1
# 705                 Santos Dumont     1
# 719           São Gonçalo do Pará     2
# 722                   São Gotardo     4
# 724             São João da Lagoa     2
# 736          São Joaquim de Bicas     1
# 764          São Vicente de Minas     3
# 767                       Sarzedo     1
# 771                Senador Cortes     3
# 800            Taquaraçu de Minas     2
# 804                       Timóteo     1
# 810                        Tombos     3
# 815                   Tupaciguara     1
# 821                       Uberaba     1
# 822                    Uberlândia     1
# 839                     Veríssimo     2
# 841                    Vespasiano     1
# 844                Mathias Lobato     2
#
# [84 rows x 2 columns]

# %%
# municípios significativos
cidades_escolhidas = mg.iloc[mun_sig.index, :]
cidades_escolhidas
# Out:
#                        NM_MUNICIP      mun  \
# 6                   ÁGUA COMPRIDA  3100708
# 22                  ALTO RIO DOCE  3102100
# 29                    ANDRELÂNDIA  3102803
# 37                       ARAGUARI  3103504
# 64                  BELMIRO BRAGA  3106101
# 65                 BELO HORIZONTE  3106200
# 69                     BERTÓPOLIS  3106606
# 71                          BETIM  3106705
# 72                    BIAS FORTES  3106804
# 73                          BICAS  3106903
# 76               BOCAINA DE MINAS  3107208
# 79            BOM JARDIM DE MINAS  3107505
# 96                     BRUMADINHO  3109006
# 107                  CAETANÓPOLIS  3109907
# 135                  CAPIM BRANCO  3112505
# 138                 CAPITÃO ENÉAS  3112703
# 160                     CARVALHOS  3114808
# 174                       CHÁCARA  3115904
# 181              CLARO DOS POÇÕES  3116506
# 191      CONCEIÇÃO DO MATO DENTRO  3117504
# 200                     CONQUISTA  3118205
# 202              CONSELHEIRO PENA  3118403
# 204                      CONTAGEM  3118601
# 214               CORONEL PACHECO  3119609
# 235                         DELTA  3121258
# 267           ENTRE RIOS DE MINAS  3123908
# 269                    ESMERALDAS  3124104
# 278              EWBANK DA CÂMARA  3125002
# 296                  FRANCISCO SÁ  3126703
# 308                  GLAUCILÂNDIA  3127354
# ..                            ...      ...
# 577                         PEQUI  3149606
# 578                      PERDIGÃO  3149705
# 582                      PESCADOR  3150000
# 583                          PIAU  3150109
# 615                         PRATA  3152808
# 623            PRUDENTE DE MORAIS  3153608
# 635            RIBEIRÃO DAS NEVES  3154606
# 641                    RIO ESPERA  3155207
# 657                        SABARÁ  3156700
# 664  SANTA BÁRBARA DO MONTE VERDE  3157278
# 673                   SANTA LUZIA  3157807
# 681            SANTANA DO DESERTO  3158607
# 685            SANTANA DO PARAÍSO  3158953
# 705                 SANTOS DUMONT  3160702
# 719           SÃO GONÇALO DO PARÁ  3161809
# 722                   SÃO GOTARDO  3162104
# 724             SÃO JOÃO DA LAGOA  3162252
# 736          SÃO JOAQUIM DE BICAS  3162922
# 764          SÃO VICENTE DE MINAS  3165305
# 767                       SARZEDO  3165537
# 771                SENADOR CORTES  3165602
# 800            TAQUARAÇU DE MINAS  3168309
# 804                       TIMÓTEO  3168705
# 810                        TOMBOS  3169208
# 815                   TUPACIGUARA  3169604
# 821                       UBERABA  3170107
# 822                    UBERLÂNDIA  3170206
# 839                     VERÍSSIMO  3171105
# 841                    VESPASIANO  3171204
# 844                MATHIAS LOBATO  3171501
#
#                                               geometry  \
# 6    POLYGON ((-47.98116005400004 -20.0364314116079...
# 22   POLYGON ((-43.47048499999999 -20.9395049966304...
# 29   POLYGON ((-44.16355900000003 -21.5893919966461...
# 37   POLYGON ((-48.34163695400002 -18.3697063945649...
# 64   POLYGON ((-43.37457 -21.89595999565354, -43.37...
# 65   POLYGON ((-43.94607618500001 -19.7772410846014...
# 69   POLYGON ((-40.46635200000004 -16.8371219975236...
# 71   POLYGON ((-44.16203548200001 -19.8422063246030...
# 72   POLYGON ((-43.70609699999999 -21.5852889966460...
# 73   POLYGON ((-43.02910899999996 -21.6757369966483...
# 76   POLYGON ((-44.43030899999997 -22.1154269966586...
# 79   POLYGON ((-44.09086999999985 -21.7968769966511...
# 96   POLYGON ((-44.00113500000004 -20.0566579966084...
# 107  POLYGON ((-44.299039 -19.4034519965919, -44.33...
# 135  POLYGON ((-44.19810699999995 -19.6421699965978...
# 138  POLYGON ((-43.62028399999997 -15.7853539974945...
# 160  POLYGON ((-44.37931699999999 -21.9408039966545...
# 174  POLYGON ((-43.16923700000001 -21.6176179966468...
# 181  POLYGON ((-44.13012899999999 -16.8214109975231...
# 191  POLYGON ((-43.73597399999995 -18.6241839975715...
# 200  POLYGON ((-47.48959070599994 -19.9693031366062...
# 202  POLYGON ((-41.13713652099988 -18.8906058905785...
# 204  POLYGON ((-44.016769357 -19.83077612360273, -4...
# 214  POLYGON ((-43.26333500000003 -21.5449029966450...
# 235  POLYGON ((-47.757479 -19.90324699660459, -47.7...
# 267  POLYGON ((-44.04303700000003 -20.6255359966226...
# 269  POLYGON ((-44.22255299999997 -19.5993489965968...
# 278  POLYGON ((-43.47285499999997 -21.5305919956447...
# 296  POLYGON ((-43.26026299999996 -16.1210599975038...
# 308  POLYGON ((-43.620411 -16.98939399752785, -43.6...
# ..                                                 ...
# 577  POLYGON ((-44.55786299999988 -19.5367029965952...
# 578  POLYGON ((-44.964837 -19.93479599660532, -44.9...
# 582  POLYGON ((-41.41909699999988 -18.2816019975625...
# 583  POLYGON ((-43.30064200000005 -21.4323279966424...
# 615  POLYGON ((-48.82355399999996 -19.1033509965841...
# 623  POLYGON ((-44.03911099999999 -19.4244499965924...
# 635  POLYGON ((-44.00555425899994 -19.7371406686003...
# 641  POLYGON ((-43.55274500000001 -20.7789409966264...
# 657  POLYGON ((-43.70842700000004 -19.7466019966005...
# 664  POLYGON ((-43.66548700000006 -21.8534039966524...
# 673  POLYGON ((-43.77044900000004 -19.7255139966000...
# 681  POLYGON ((-43.18878399999996 -21.8545699966524...
# 685  POLYGON ((-42.55499900000001 -19.2963919965891...
# 705  POLYGON ((-43.46978399999998 -21.3714789966408...
# 719  POLYGON ((-44.81598299999995 -19.8927059966043...
# 722  POLYGON ((-45.83388099999996 -19.1796609965860...
# 724  POLYGON ((-44.14598900000006 -16.7261579975206...
# 736  POLYGON ((-44.19628799999999 -20.0511519966082...
# 764  POLYGON ((-44.38644899999999 -21.5861139966460...
# 767  POLYGON ((-44.11605799999997 -20.0236339966075...
# 771  POLYGON ((-42.86832900000001 -21.7033339966488...
# 800  POLYGON ((-43.62885899999999 -19.6945799965992...
# 804  POLYGON ((-42.51431508599992 -19.4923094095941...
# 810  POLYGON ((-41.92973805099995 -20.8435882486279...
# 815  POLYGON ((-48.917744685 -18.30587944156323, -4...
# 821  POLYGON ((-47.85263799999996 -19.0938939965838...
# 822  POLYGON ((-48.06138999999996 -18.8858269975785...
# 839  POLYGON ((-48.35521299999994 -19.4118079965920...
# 841  POLYGON ((-43.94488110199998 -19.6716266525986...
# 844  POLYGON ((-41.97204599999995 -18.5343479975692...
#
#                          nome_mun       nome_uf  uf                 rm  meso  \
# 6                   Água Comprida  Minas Gerais  31                nao  3105
# 22                  Alto Rio Doce  Minas Gerais  31                nao  3112
# 29                    Andrelândia  Minas Gerais  31                nao  3110
# 37                       Araguari  Minas Gerais  31                nao  3105
# 64                  Belmiro Braga  Minas Gerais  31                nao  3112
# 815                   Tupaciguara  Minas Gerais  31                nao  3105
# 821                       Uberaba  Minas Gerais  31                nao  3105
# 822                    Uberlândia  Minas Gerais  31                nao  3105
# 839                     Veríssimo  Minas Gerais  31                nao  3105
# 841                    Vespasiano  Minas Gerais  31  RM Belo Horizonte  3107
# 844                Mathias Lobato  Minas Gerais  31                nao  3108
#
#                             nome_meso  micro  ...       porte    vab_agro  \
# 6    Triângulo Mineiro/Alto Paranaíba  31022  ...    pequenoI   43434.608
# 22                       Zona da Mata  31062  ...    pequenoI   28524.445
# 29              Sul/Sudoeste de Minas  31055  ...    pequenoI   15014.099
# 37   Triângulo Mineiro/Alto Paranaíba  31018  ...     medioII  161648.492
# 64                       Zona da Mata  31065  ...    pequenoI    5050.731
# 65    Metropolitana de Belo Horizonte  31030  ...    grandeII     833.082
# 69                     Vale do Mucuri  31016  ...    pequenoI    3934.179
# 71    Metropolitana de Belo Horizonte  31030  ...     medioII   10122.979
# 72                       Zona da Mata  31065  ...    pequenoI    3407.888
# 73                       Zona da Mata  31065  ...    pequenoI    2882.507
# 76              Sul/Sudoeste de Minas  31055  ...    pequenoI    3277.903
# 79              Sul/Sudoeste de Minas  31055  ...    pequenoI    2396.676
# 96    Metropolitana de Belo Horizonte  31030  ...   pequenoII   15511.552
# 107   Metropolitana de Belo Horizonte  31027  ...    pequenoI   18232.529
# 135   Metropolitana de Belo Horizonte  31027  ...    pequenoI    1579.059
# 138                    Norte de Minas  31007  ...    pequenoI   18916.523
# 160             Sul/Sudoeste de Minas  31055  ...    pequenoI    4110.345
# 174                      Zona da Mata  31065  ...    pequenoI    6369.349
# 181                    Norte de Minas  31007  ...    pequenoI   13101.978
# 191   Metropolitana de Belo Horizonte  31028  ...    pequenoI   14041.910
# 200  Triângulo Mineiro/Alto Paranaíba  31022  ...    pequenoI   46462.866
# 202                  Vale do Rio Doce  31041  ...   pequenoII   26721.657
# 204   Metropolitana de Belo Horizonte  31030  ...     grandeI    1121.452
# 214                      Zona da Mata  31065  ...    pequenoI    3313.864
# 235  Triângulo Mineiro/Alto Paranaíba  31022  ...    pequenoI    8310.756
# 267   Metropolitana de Belo Horizonte  31034  ...    pequenoI   12711.547
# 269   Metropolitana de Belo Horizonte  31030  ...      medioI   29615.716
# 278                      Zona da Mata  31065  ...    pequenoI    1463.953
# 296                    Norte de Minas  31007  ...   pequenoII   29996.429
# 308                    Norte de Minas  31007  ...    pequenoI    3215.517
# ..                                ...    ...  ...         ...         ...
# 577   Metropolitana de Belo Horizonte  31027  ...    pequenoI    8893.972
# 578                    Oeste de Minas  31043  ...    pequenoI    9815.543
# 582                  Vale do Rio Doce  31037  ...    pequenoI    4651.352
# 583                      Zona da Mata  31065  ...    pequenoI    4941.473
# 615  Triângulo Mineiro/Alto Paranaíba  31018  ...   pequenoII  157642.168
# 623   Metropolitana de Belo Horizonte  31027  ...    pequenoI    1965.122
# 635   Metropolitana de Belo Horizonte  31030  ...     medioII    2482.434
# 641                      Zona da Mata  31062  ...    pequenoI    4339.581
# 6    7.934957e+04  39281.97     2
# 22   7.930831e+04   6523.14     3
# 29   9.738629e+04   8017.97     3
# 37   2.147789e+06  19564.66     1
# 64   3.013104e+04   8851.66     2
# 65   5.920307e+07  24922.95     1
# 69   2.436970e+04   5417.90     3
# 71   2.338491e+07  61939.08     1
# 72   2.082221e+04   5485.30     2
# 73   1.205599e+05   8830.29     2
# 76   4.064111e+04   8128.22     3
# 79   7.783964e+04  11951.43     3
# 96   1.335180e+06  39254.99     1
# 107  1.485020e+05  14520.58     2
# 135  6.232190e+04   7018.23     2
# 138  1.555846e+05  10952.04     2
# 160  2.679665e+04   5882.91     3
# 174  2.341407e+04   8386.13     2
# 181  4.492613e+04   5773.82     2
# 191  1.558946e+05   8702.39     3
# 200  1.178393e+05  18054.13     2
# 202  1.597575e+05   7185.93     3
# 204  1.914264e+07  31743.14     1
# 214  2.177054e+04   7298.20     2
# 235  2.351871e+05  29010.38     2
# 267  9.811702e+04   6879.61     3
# 269  3.254460e+05   5410.30     1
# 278  2.174835e+04   5796.47     2
# 296  1.508763e+05   6054.91     1
# 308  1.575240e+04   5314.58     2
# ..            ...       ...   ...
# 577  3.089799e+04   7582.33     3
# 578  7.557034e+04   8479.62     2
# 582  2.406515e+04   5828.32     3
# 583  2.853491e+04  10033.37     2
# 615  5.411734e+05  20971.65     1
# 623  6.935994e+04   7243.10     2
# 635  1.733699e+06   5849.66     1
# 641  2.418158e+04   3978.54     3
# 657  1.356782e+06  10749.43     1
# 664  2.172115e+04   7788.15     2
# 673  2.230852e+06  10979.47     1
# 681  2.038662e+04   5289.73     2
# 685  2.760562e+05  10127.53     1
# 705  5.154835e+05  11136.20     1
# 719  1.018194e+05   9785.63     2
# 722  3.456144e+05  10865.98     4
# 724  2.587910e+04   5554.65     2
# 736  3.854765e+05  15046.51     1
# 764  6.718843e+04   9587.39     3
# 767  3.948517e+05  15305.52     1
# 771  1.253239e+04   6329.49     3
# 800  3.246328e+04   8560.99     2
# 804  2.036766e+06  25108.37     1
# 810  6.233258e+04   6532.44     3
# 815  2.826327e+05  11686.28     1
# 821  7.299720e+06  24661.21     1
# 822  1.895058e+07  31569.30     1
# 839  7.005785e+04  20212.88     2
# 841  1.561162e+06  14923.36     1
# 844  1.830049e+04   5428.80     2
#
# [84 rows x 83 columns]

# %%
# plotar os nomes dos clusters e outliers espaciais 
fig = plt.figure(figsize=(20, 15))
shp = ps.open(shapefile)
base = maps.map_poly_shp(shp)
base = maps.base_lisa_cluster(base, lisa, p_thres=p_thres)
base.set_edgecolor('1')
base.set_linewidth(0.1)
ax = maps.setup_ax([base], [shp.bbox])

boxes, labels = maps.lisa_legend_components(lisa, p_thres=p_thres)
plt.legend(boxes, labels, fancybox=True)

for i in cidades_escolhidas.index:

    plt.text(cidades_escolhidas.geometry.centroid[i].coords[0][0], cidades_escolhidas.geometry.centroid[i].coords[0][1], 
             cidades_escolhidas.nome_mun[i],
             fontsize=10, horizontalalignment='center', verticalalignment='bottom')

# %% [markdown]
# Tentar plotar os nomes dos municípios que são *outliers* espaciais.
