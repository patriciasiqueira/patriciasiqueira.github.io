# %% [markdown]
# ### *Notebook* de exemplo para o trabalho final de Fundamentos da Programação (2017/2)

# %%
# importar o pacote pandas - útil para dataframes, séries, dados em painel
import pandas as pd

# %%
# ler a planilha 'imrs', que está no formato csv
imrs = pd.read_csv('imrs.csv')

# %%
# ver as variáveis contidas no dataframe
imrs.columns
# Out:
# Index(['ibge7', 'meso', 'nome_meso', 'micro', 'nome_micro', 'mun',
#        'tx_mort_acid_15_29', 'tx_mort_hom_15_29', 'tx_mort_mama',
#        'tx_mort_inf', 'existe_conselho_saude', 'tx_analf_25m', 'prop_fund_25m',
#        'perc_med_25m', 'tx_med_adeq', 'tx_med_lab', 'existe_conselho_educ',
#        'tx_crimes_pat', 'tx_crimes_pes', 'tx_hom', 'existe_uni_infra',
#        'perc_energia', 'perc_banagua', 'perc_esgoto', 'perc_lixo', 'pop_total',
#        'pop_masc', 'pop_fem', 'raz_dep', 'tx_urb', 'tx_fec', 'esp_vida',
#        'rdpc', 'renocup', 'perc_rdpc_140', 'fam_pbf', 'tx_emp_form',
#        'rend_pc_form', 'pib_pc', 'perc_agro', 'perc_serv', 'tx_ativ_18m'],
#       dtype='object')

# %%
# função que mostra as 5 primeiras observações do dataframe
imrs.head()
# Out:
#      ibge7  meso                         nome_meso  micro   nome_micro  \
# 0  3100104  3105  Triângulo Mineiro/Alto Paranaíba  31019   Patrocínio
# 1  3100203  3106                   Central Mineira  31024  Três Marias
# 2  3100302  3112                      Zona da Mata  31061     Manhuaçu
# 3  3100401  3112                      Zona da Mata  31060   Ponte Nova
# 4  3100500  3108                  Vale do Rio Doce  31039     Ipatinga
#
#                    mun  tx_mort_acid_15_29  tx_mort_hom_15_29  tx_mort_mama  \
# 0  Abadia dos Dourados               66.53               0.00          0.00
# 1               Abaeté               56.22               0.00          8.73
# 2           Abre Campo               30.90               0.00          0.00
# 3              Acaiaca                0.00               0.00          0.00
# 4              Açucena                0.00              34.13          0.00
#
#    tx_mort_inf     ...         rdpc  renocup  perc_rdpc_140  fam_pbf  \
# 0         0.00     ...       596.18   920.10           7.94      589
# 1        27.27     ...       707.24   930.85           6.69     1428
# 2        27.21     ...       444.32   685.72          23.33     1293
# 3        20.83     ...       357.03   646.71          26.53      389
# 4        19.61     ...       325.42   514.60          30.70     1172
#
#    tx_emp_form  rend_pc_form    pib_pc  perc_agro  perc_serv  tx_ativ_18m
# 0         22.9        114.28  11744.69      37.90      26.86        65.97
# 1         27.5        172.19  11466.39      22.08      40.06        65.90
# 2         20.1        117.72   7998.32      45.80      31.92        63.80
# 3         11.7         61.49   6049.45      25.16      41.87        57.71
# 4         10.3         52.78   5603.93      41.22      29.89        54.21
#
# [5 rows x 42 columns]

# %%
# retorna a dimensão do dataframe (linhas e colunas)
imrs.shape
# Out:
# (853, 42)

# %%
# retorna o número de linhas
len(imrs)
# Out:
# 853

# %% [markdown]
# Para exemplificar o uso de uma estrutura de repetição (*for*) e uma estrutura condicional (*if*) fiz a seguinte pergunta:

# %% [markdown]
# Quais os municípios de MG possuem renda *per capita* maior do que R$1000,00?

# %%
# municípios de MG possuem renda per capita maior do que R$1000?
# percorrer cada linha do dataframe e verificar se o valor da variável rdpc
# é maior do que 1000. Se for, mostrar o nome do município e o valor de rdpc
for i in range(len(imrs)):
    if imrs.rdpc[i] > 1000:
        print(imrs.mun[i], imrs.rdpc[i])
# Out:
# Belo Horizonte 1497.29
# Jequitibá 1007.03
# Juiz de Fora 1050.88
# Juruaia 1122.1
# Lagoa Santa 1089.96
# Nova Lima 1731.84
# Uberlândia 1001.45

# %% [markdown]
# Note que bastaria trocar a variável (escolher outra no lugar de *rdpc*) e o valor de referência (1000) para fazer outra consulta. **Muito importante:** essa modificação **NÃO CONTA** como um uso diferente para o *for* e para o *if*, já que nada de novo está sendo feito no código:

# %%
# usando a mesma estrutura acima para responder quais os municípios de MG 
# possuem fecundidade total maior do que 3
# mostrar o nome do município e o valor de tx_fec
for i in range(len(imrs)):
    if imrs.tx_fec[i] > 3:
        print(imrs.mun[i], imrs.tx_fec[i])
# Out:
# Bertópolis 3.13
# Botumirim 3.22
# Campo Azul 3.08
# Crisólita 3.01
# Cristália 3.06
# Matias Cardoso 3.13
# Monte Formoso 3.01
# Santa Helena de Minas 3.13
# São João das Missões 3.15
# São José da Safira 3.13
# Setubinha 3.1
# Verdelândia 3.13

# %% [markdown]
# Se fôssemos usar uma função pronta do pacote *pandas* (o que não é nosso foco na disciplina), bastaria fazer o seguinte (porém ele retornaria um *dataframe* inteiro com as linhas selecionadas (tx_fec > 3)):

# %%
imrs[imrs.tx_fec > 3]
# Out:
#        ibge7  meso         nome_meso  micro            nome_micro  \
# 69   3106606  3104    Vale do Mucuri  31016               Nanuque
# 90   3108503  3102    Norte de Minas  31008            Grão Mogol
# 120  3111150  3102    Norte de Minas  31007         Montes Claros
# 221  3120151  3104    Vale do Mucuri  31016               Nanuque
# 223  3120300  3102    Norte de Minas  31008            Grão Mogol
# 472  3140852  3102    Norte de Minas  31003              Januária
# 497  3143153  3103     Jequitinhonha  31014              Almenara
# 672  3157658  3104    Vale do Mucuri  31016               Nanuque
# 728  3162450  3102    Norte de Minas  31003              Januária
# 740  3163003  3108  Vale do Rio Doce  31037  Governador Valadares
# 769  3165552  3104    Vale do Mucuri  31015         Teófilo Otoni
# 838  3171030  3102    Norte de Minas  31007         Montes Claros
#
#                        mun  tx_mort_acid_15_29  tx_mort_hom_15_29  \
# 69              Bertópolis                0.00               0.00
# 90               Botumirim                0.00               0.00
# 120             Campo Azul                0.00               0.00
# 221              Crisólita                0.00               0.00
# 223              Cristália                0.00               0.00
# 472         Matias Cardoso               33.75               0.00
# 497          Monte Formoso               88.03               0.00
# 672  Santa Helena de Minas                0.00               0.00
# 728   São João das Missões                0.00              61.63
# 740     São José da Safira                0.00               0.00
# 769              Setubinha               34.20              31.86
# 838            Verdelândia               39.11               0.00
#
#      tx_mort_mama  tx_mort_inf     ...         rdpc  renocup  perc_rdpc_140  \
# 69           47.3        63.06     ...       288.77   480.44          38.66
# 90            0.0        27.40     ...       230.25   360.58          39.74
# 120           0.0        20.00     ...       244.97   332.99          38.16
# 221           0.0         0.00     ...       294.11   537.82          35.67
# 223           0.0        10.31     ...       200.51   364.26          46.63
# 472           0.0         6.58     ...       303.00   593.22          39.94
# 497           0.0        16.95     ...       206.62   346.88          55.76
# 672           0.0        72.16     ...       218.43   370.10          47.38
# 728           0.0        10.87     ...       181.77   363.20          53.37
# 740           0.0        15.15     ...       334.87   553.69          24.85
# 769           0.0        43.01     ...       224.63   367.22          50.45
# 838           0.0        18.99     ...       233.27   486.72          37.92
#
#      fam_pbf  tx_emp_form  rend_pc_form   pib_pc  perc_agro  perc_serv  \
# 69       662          7.1         32.83  6453.33      48.53      32.22
# 90       966         14.7         71.84  5285.22      56.94      25.82
# 120      545         10.0         37.62  6011.30      48.96      33.50
# 221      849         10.8         59.20  6388.64      58.32      22.91
# 223      890         12.8         66.65  6163.51      55.98      25.32
# 472     1160         21.1         86.16  9383.59      46.95      30.34
# 497      581         11.3         62.38  4101.41      49.92      26.12
# 672      718          5.8         27.04  4554.04      47.94      32.33
# 728     1573          5.7         23.58  3594.08      54.82      30.30
# 740      496         11.1         68.27  5251.28      25.25      26.62
# 769     1430          5.4         22.90  3856.07      66.21      19.18
# 838     1104         15.8         68.01  8153.69      54.05      29.70
#
#      tx_ativ_18m
# 69         61.02
# 90         64.34
# 120        64.90
# 221        57.76
# 223        61.21
# 472        62.43
# 497        52.37
# 672        51.69
# 728        57.96
# 740        63.25
# 769        63.40
# 838        62.31
#
# [12 rows x 42 columns]

# %% [markdown]
# Agora um exemplo de uso de listas. Eu quero responder a mesma pergunta sobre renda, mas o resultado será apresentado em uma lista.

# %%
# lista de listas: 
# quais os municípios do Brasil possuem renda per capita maior do que R$1000?
# percorrer cada linha do dataframe e verificar se o valor da variável rdpc
# é maior do que 1000. Se for, colocar o nome do município e a renda numa lista
lista_rdpc = []
for i in range(len(imrs)):
    if imrs.rdpc[i] > 1000:
        lista_rdpc.append([imrs.mun[i], imrs.rdpc[i]])

# visualizar a lista criada
lista_rdpc
# Out:
# [['Belo Horizonte', 1497.29],
#  ['Jequitibá', 1007.03],
#  ['Juiz de Fora', 1050.8800000000001],
#  ['Juruaia', 1122.0999999999999],
#  ['Lagoa Santa', 1089.96],
#  ['Nova Lima', 1731.8399999999999],
#  ['Uberlândia', 1001.45]]

# %% [markdown]
# Como é uma lista, posso acessar seus elementos:

# %%
# elemento da posição 4 da lista
lista_rdpc[4]
# Out:
# ['Lagoa Santa', 1089.96]

# %%
# elemento da posição 4 é uma lista, quero a posição 1 dessa sublista
lista_rdpc[4][1]
# Out:
# 1089.96

# %% [markdown]
# Exemplo do uso de funções:

# %%
# transformando em função que recebe o dataframe como parâmetro
# e retorna na tela o nome do município e a rdpc 
# dos municípios de MG que têm rdpc > 1000
def acima_rdpc(df):
    for i in range(len(df)):
        if df.rdpc[i] > 1000:
            print(df.mun[i], df.rdpc[i])

# uso da função
acima_rdpc(imrs)
# Out:
# Belo Horizonte 1497.29
# Jequitibá 1007.03
# Juiz de Fora 1050.88
# Juruaia 1122.1
# Lagoa Santa 1089.96
# Nova Lima 1731.84
# Uberlândia 1001.45

# %% [markdown]
# Essa função é sem graça porque é meio "travada". Os parâmetros são interessantes para podermos retornar vários resultados interessantes com flexibilidade.

# %%
# melhorando a função acima: outro parâmetro que indica qual o 
# valor de referência
def acima_rdpc_valor(df, valor):
    for i in range(len(df)):
        if df.rdpc[i] > valor:
            print(df.mun[i], df.rdpc[i])

# uso da função
acima_rdpc_valor(imrs, 1100)
# Out:
# Belo Horizonte 1497.29
# Juruaia 1122.1
# Nova Lima 1731.84

# %% [markdown]
# Exemplo de interação com o usuário: ele define o valor de renda *per capita* a partir do qual ele deseja saber os municípios que apresentam esse valor.

# %%
# interação com o usuário
valor = float(input('Acima de qual valor de renda você deseja visualizar os municípios de MG? '))

# uso da função
acima_rdpc_valor(imrs, valor)
# Out:
# Acima de qual valor de renda você deseja visualizar os municípios de MG? 1000
# Belo Horizonte 1497.29
# Jequitibá 1007.03
# Juiz de Fora 1050.88
# Juruaia 1122.1
# Lagoa Santa 1089.96
# Nova Lima 1731.84
# Uberlândia 1001.45

# %%
# outra variação da mesma função: uma lista é criada com as informações
def acima_rdpc_valor(df, valor):
    lista = []
    for i in range(len(df)):
        if df.rdpc[i] > valor:
            lista.append([df.mun[i], df.rdpc[i]])
    return lista

# uso da função
acima_rdpc_valor(imrs, 1100)
# Out:
# [['Belo Horizonte', 1497.29],
#  ['Juruaia', 1122.0999999999999],
#  ['Nova Lima', 1731.8399999999999]]

# %% [markdown]
# A função *describe* fornece um resumo estatístico da variável, o que pode ajudar em alguns cálculos:

# %%
# como é a variável tx_mort_acid_15_29, por exemplo? Seu resumo estatístico é dado por:
imrs.tx_mort_acid_15_29.describe()
# Out:
# count    853.000000
# mean      33.856401
# std       56.497675
# min        0.000000
# 25%        0.000000
# 50%       10.900000
# 75%       50.530000
# max      607.900000
# Name: tx_mort_acid_15_29, dtype: float64

# %%
# função mais geral - as informações passadas como parâmetros são:
# - dataframe
# - variável
# - valor de referência
# a função retorna o nome do município e o valor da variável para
# os municípios que têm valores maiores do que o que foi passado
# como parâmetro
def municipios_acima(df, var, valor):
    lista = []
    for i in range(len(df)):
        if df[var][i] > valor:
            lista.append([df.mun[i], df[var][i]])
    return lista

# uso da função
municipios_acima(imrs, 'tx_mort_acid_15_29', 230)
# Out:
# [['Carvalhos', 281.16000000000003],
#  ['Casa Grande', 546.45000000000005],
#  ['Cedro do Abaeté', 393.69999999999999],
#  ['Consolação', 264.55000000000001],
#  ['Cristiano Otoni', 239.22999999999999],
#  ['Dom Cavati', 339.85000000000002],
#  ['Dores do Turvo', 297.02999999999997],
#  ['Douradoquara', 234.19],
#  ['Entre Folhas', 242.72],
#  ['Paiva', 607.89999999999998],
#  ['São José do Alegre', 330.75999999999999]]

# %% [markdown]
# Interação com o usuário na função *municípios_acima*:

# %%
print('Insira a variável e qual o valor a partir do qual deseja ver os municípios que atendem ao critério:')
var = input('variável: ')
valor = float(input('valor: '))

municipios_acima(imrs, var, valor)
# Out:
# Insira a variável e qual o valor a partir do qual deseja ver os municípios que atendem ao critério:
# variável: tx_fec
# valor: 3
# [['Bertópolis', 3.1299999999999999],
#  ['Botumirim', 3.2200000000000002],
#  ['Campo Azul', 3.0800000000000001],
#  ['Crisólita', 3.0099999999999998],
#  ['Cristália', 3.0600000000000001],
#  ['Matias Cardoso', 3.1299999999999999],
#  ['Monte Formoso', 3.0099999999999998],
#  ['Santa Helena de Minas', 3.1299999999999999],
#  ['São João das Missões', 3.1499999999999999],
#  ['São José da Safira', 3.1299999999999999],
#  ['Setubinha', 3.1000000000000001],
#  ['Verdelândia', 3.1299999999999999]]

# %% [markdown]
# Agora uma função mais simples: calcular a soma de valores dos municípios em relação a uma variável:

# %%
# função para calcular a soma dos valores de uma variável 
# para o dataframe
def soma(df, var):
    soma = 0
    for i in range(len(df)):
        soma = soma + df[var][i]
    return soma

# uso da função
soma(imrs, 'pop_total')
# Out:
# 19595309

# %%
# conferir com a função pronta do pandas
imrs.pop_total.sum()
# Out:
# 19595309

# %%
# função para retornar o município com maior valor de uma variável
# para iniciar, o candidato a maior é o primeiro município
def maior(df, var):
    # a lista 'maior' tem nome na pos. 0 e o valor da variável 
    # do 1. município na pos. 1
    maior = [df.mun[0], df.nome_meso[0], df[var][0]] 
    for i in range(len(df)):   # percorrer o dataframe em busca do maior valor
        if df[var][i] > maior[2]: # comparar o valor da variável na posição i
                                  # com o valor da variável na lista 'maior'
            maior = [df.mun[i], df.nome_meso[i], df[var][i]] # subtitui pelo novo maior encontrado
    return maior

# uso da função
maior(imrs, 'perc_esgoto')
# Out:
# ['Santa Cruz de Minas', 'Campo das Vertentes', 98.219999999999999]

# %%
# usando função pronta do pandas
# que retorna os maiores valores de uma variável
imrs.sort_values(by='perc_esgoto', ascending=False).loc[:,['mun', 'nome_meso', 'perc_esgoto']]
# Out:
#                       mun                         nome_meso  perc_esgoto
# 667   Santa Cruz de Minas               Campo das Vertentes        98.22
# 356              Ipatinga                  Vale do Rio Doce        97.59
# 604       Poços de Caldas             Sul/Sudoeste de Minas        97.05
# 747          São Lourenço             Sul/Sudoeste de Minas        96.86
# 823            Uberlândia  Triângulo Mineiro/Alto Paranaíba        96.42
# 822               Uberaba  Triângulo Mineiro/Alto Paranaíba        96.38
# 381         Itaú de Minas             Sul/Sudoeste de Minas        96.24
# 43                  Araxá  Triângulo Mineiro/Alto Paranaíba        96.06
# 833              Varginha             Sul/Sudoeste de Minas        96.04
# 65         Belo Horizonte   Metropolitana de Belo Horizonte        95.66
# 40                Araporã  Triângulo Mineiro/Alto Paranaíba        95.63
# 170               Caxambu             Sul/Sudoeste de Minas        95.28
# 425        Lagoa da Prata                   Central Mineira        95.12
# 382                Itaúna                    Oeste de Minas        94.67
# 558                Passos             Sul/Sudoeste de Minas        94.35
# 104    Cachoeira da Prata   Metropolitana de Belo Horizonte        94.24
# 789           Sete Lagoas   Metropolitana de Belo Horizonte        94.10
# 386             Ituiutaba  Triângulo Mineiro/Alto Paranaíba        93.56
# 684     Santana do Jacaré                    Oeste de Minas        93.48
# 602               Planura  Triângulo Mineiro/Alto Paranaíba        93.28
# 436                Lavras               Campo das Vertentes        93.23
# 15                Alfenas             Sul/Sudoeste de Minas        93.20
# 530       Olímpio Noronha             Sul/Sudoeste de Minas        93.08
# 73                  Bicas                      Zona da Mata        93.04
# 550         Pará de Minas   Metropolitana de Belo Horizonte        92.98
# 121            Campo Belo                    Oeste de Minas        92.95
# 805               Timóteo                  Vale do Rio Doce        92.95
# 410        João Monlevade   Metropolitana de Belo Horizonte        92.66
# 524          Nova Serrana                    Oeste de Minas        92.58
# 419          Juiz de Fora                      Zona da Mata        92.06
# ..                    ...                               ...          ...
# 443                Lontra                    Norte de Minas         0.32
# 687     Santana do Riacho   Metropolitana de Belo Horizonte         0.31
# 177        Chapada Gaúcha                    Norte de Minas         0.26
# 727     São João da Ponte                    Norte de Minas         0.26
# 120            Campo Azul                    Norte de Minas         0.24
# 271              Espinosa                    Norte de Minas         0.21
# 540        Padre Carvalho                    Norte de Minas         0.17
# 282    Felício dos Santos                     Jequitinhonha         0.16
# 487             Miravânia                    Norte de Minas         0.15
# 591            Pintópolis                    Norte de Minas         0.13
# 195        Cônego Marinho                    Norte de Minas         0.12
# 247         Divisa Alegre                    Norte de Minas         0.11
# 422             Juvenília                    Norte de Minas         0.10
# 527           Novorizonte                    Norte de Minas         0.10
# 303        Fruta de Leite                    Norte de Minas         0.08
# 820                  Ubaí                    Norte de Minas         0.08
# 733     São João do Pacuí                    Norte de Minas         0.07
# 404              Jequitaí                    Norte de Minas         0.06
# 291               Formoso                 Noroeste de Minas         0.03
# 87        Bonito de Minas                    Norte de Minas          NaN
# 196               Confins   Metropolitana de Belo Horizonte          NaN
# 307            Gameleiras                    Norte de Minas          NaN
# 400              Japonvar                    Norte de Minas          NaN
# 445            Luislândia                    Norte de Minas          NaN
# 490              Monjolos                   Central Mineira          NaN
# 544             Pai Pedro                    Norte de Minas          NaN
# 559                 Patis                    Norte de Minas          NaN
# 588    Piedade dos Gerais   Metropolitana de Belo Horizonte          NaN
# 728  São João das Missões                    Norte de Minas          NaN
# 787              Serranos             Sul/Sudoeste de Minas          NaN
#
# [853 rows x 3 columns]

# %%
# só mostrando os 5 primeiros
(imrs
 .sort_values(by='perc_esgoto', ascending=False)
 .loc[:,['mun', 'nome_meso', 'perc_esgoto']]
 .iloc[:5,:])
# Out:
#                      mun                         nome_meso  perc_esgoto
# 667  Santa Cruz de Minas               Campo das Vertentes        98.22
# 356             Ipatinga                  Vale do Rio Doce        97.59
# 604      Poços de Caldas             Sul/Sudoeste de Minas        97.05
# 747         São Lourenço             Sul/Sudoeste de Minas        96.86
# 823           Uberlândia  Triângulo Mineiro/Alto Paranaíba        96.42

# %% [markdown]
# ## Selecionar municípios de MG (por mesorregião ou microrregião)

# %%
# para saber como estão os nomes das mesorregiões
imrs.nome_meso.unique()
# Out:
# array(['Triângulo Mineiro/Alto Paranaíba', 'Central Mineira',
#        'Zona da Mata', 'Vale do Rio Doce', 'Oeste de Minas',
#        'Vale do Mucuri', 'Norte de Minas', 'Sul/Sudoeste de Minas',
#        'Campo das Vertentes', 'Jequitinhonha',
#        'Metropolitana de Belo Horizonte', 'Noroeste de Minas'], dtype=object)

# %%
# criar um objeto sul com os municípios apenas do Sul/Sudoeste de MG
sul = imrs.query("nome_meso == 'Sul/Sudoeste de Minas'")

# %%
sul.shape
# Out:
# (146, 42)

# %%
# notar que os índices começam em 11
sul.head()
# Out:
#       ibge7  meso              nome_meso  micro       nome_micro          mun  \
# 11  3101201  3110  Sul/Sudoeste de Minas  31055      Andrelândia     Aiuruoca
# 12  3101300  3110  Sul/Sudoeste de Minas  31054     São Lourenço       Alagoa
# 13  3101409  3110  Sul/Sudoeste de Minas  31051  Poços de Caldas    Albertina
# 15  3101607  3110  Sul/Sudoeste de Minas  31049          Alfenas      Alfenas
# 19  3101904  3110  Sul/Sudoeste de Minas  31047           Passos  Alpinópolis
#
#     tx_mort_acid_15_29  tx_mort_hom_15_29  tx_mort_mama  tx_mort_inf  \
# 11                0.00               0.00          0.00        16.95
# 12                0.00               0.00          0.00         0.00
# 13                0.00               0.00          0.00         0.00
# 15               36.42              29.83         10.61        13.46
# 19               62.67              41.89         22.23        21.74
#
#        ...         rdpc  renocup  perc_rdpc_140  fam_pbf  tx_emp_form  \
# 11     ...       539.92   734.85          11.70      283         19.8
# 12     ...       413.75   558.92          17.57      263         15.7
# 13     ...       564.08   796.26           3.02      114         18.7
# 15     ...       783.41  1229.94           5.53     3263         33.5
# 19     ...       633.91  1029.25           8.46      754         21.1
#
#     rend_pc_form    pib_pc  perc_agro  perc_serv  tx_ativ_18m
# 11        113.90   9477.41      36.35      35.66        68.45
# 12        103.43   9395.80      54.15      30.50        64.49
# 13        119.71  14661.80      52.97      22.83        74.53
# 15        314.28  17398.74      11.93      47.82        68.37
# 19        133.12  12567.83      29.99      30.86        66.19
#
# [5 rows x 42 columns]

# %%
# fazer com que os índices comecem em 0
sul.index = range(len(sul))
sul.head()
# Out:
#      ibge7  meso              nome_meso  micro       nome_micro          mun  \
# 0  3101201  3110  Sul/Sudoeste de Minas  31055      Andrelândia     Aiuruoca
# 1  3101300  3110  Sul/Sudoeste de Minas  31054     São Lourenço       Alagoa
# 2  3101409  3110  Sul/Sudoeste de Minas  31051  Poços de Caldas    Albertina
# 3  3101607  3110  Sul/Sudoeste de Minas  31049          Alfenas      Alfenas
# 4  3101904  3110  Sul/Sudoeste de Minas  31047           Passos  Alpinópolis
#
#    tx_mort_acid_15_29  tx_mort_hom_15_29  tx_mort_mama  tx_mort_inf  \
# 0                0.00               0.00          0.00        16.95
# 1                0.00               0.00          0.00         0.00
# 2                0.00               0.00          0.00         0.00
# 3               36.42              29.83         10.61        13.46
# 4               62.67              41.89         22.23        21.74
#
#       ...         rdpc  renocup  perc_rdpc_140  fam_pbf  tx_emp_form  \
# 0     ...       539.92   734.85          11.70      283         19.8
# 1     ...       413.75   558.92          17.57      263         15.7
# 2     ...       564.08   796.26           3.02      114         18.7
# 3     ...       783.41  1229.94           5.53     3263         33.5
# 4     ...       633.91  1029.25           8.46      754         21.1
#
#    rend_pc_form    pib_pc  perc_agro  perc_serv  tx_ativ_18m
# 0        113.90   9477.41      36.35      35.66        68.45
# 1        103.43   9395.80      54.15      30.50        64.49
# 2        119.71  14661.80      52.97      22.83        74.53
# 3        314.28  17398.74      11.93      47.82        68.37
# 4        133.12  12567.83      29.99      30.86        66.19
#
# [5 rows x 42 columns]

# %%
# outro jeito para fazer com que os índices comecem em 0
sul1 = imrs.query("nome_meso == 'Sul/Sudoeste de Minas'").reset_index().drop('index', axis=1)
sul1.head()
# Out:
#      ibge7  meso              nome_meso  micro       nome_micro          mun  \
# 0  3101201  3110  Sul/Sudoeste de Minas  31055      Andrelândia     Aiuruoca
# 1  3101300  3110  Sul/Sudoeste de Minas  31054     São Lourenço       Alagoa
# 2  3101409  3110  Sul/Sudoeste de Minas  31051  Poços de Caldas    Albertina
# 3  3101607  3110  Sul/Sudoeste de Minas  31049          Alfenas      Alfenas
# 4  3101904  3110  Sul/Sudoeste de Minas  31047           Passos  Alpinópolis
#
#    tx_mort_acid_15_29  tx_mort_hom_15_29  tx_mort_mama  tx_mort_inf  \
# 0                0.00               0.00          0.00        16.95
# 1                0.00               0.00          0.00         0.00
# 2                0.00               0.00          0.00         0.00
# 3               36.42              29.83         10.61        13.46
# 4               62.67              41.89         22.23        21.74
#
#       ...         rdpc  renocup  perc_rdpc_140  fam_pbf  tx_emp_form  \
# 0     ...       539.92   734.85          11.70      283         19.8
# 1     ...       413.75   558.92          17.57      263         15.7
# 2     ...       564.08   796.26           3.02      114         18.7
# 3     ...       783.41  1229.94           5.53     3263         33.5
# 4     ...       633.91  1029.25           8.46      754         21.1
#
#    rend_pc_form    pib_pc  perc_agro  perc_serv  tx_ativ_18m
# 0        113.90   9477.41      36.35      35.66        68.45
# 1        103.43   9395.80      54.15      30.50        64.49
# 2        119.71  14661.80      52.97      22.83        74.53
# 3        314.28  17398.74      11.93      47.82        68.37
# 4        133.12  12567.83      29.99      30.86        66.19
#
# [5 rows x 42 columns]

# %%
# usar a função municipios_acima
# quais municípios do sul de MG possuem renda per capita maior do que 1000?
municipios_acima(sul, 'rdpc', 1000)
# Out:
# [['Juruaia', 1122.0999999999999]]

# %%
# usando a função soma
soma(sul, 'pop_total')
# Out:
# 2439168

# %%
# conferindo com a função pronta do pandas
sul.pop_total.sum()
# Out:
# 2439168

# %%
# uso da função maior (criada antes) para o conjunto de dados sul
maior(sul, 'rdpc')
# Out:
# ['Juruaia', 'Sul/Sudoeste de Minas', 1122.0999999999999]

# %%
maior(sul, 'tx_fec')
# Out:
# ['São Bento Abade', 'Sul/Sudoeste de Minas', 2.7000000000000002]

# %% [markdown]
# O próximo exemplo é de uma função que não faz quase nada, mas é para exemplificar o caso em que o usuário inserir uma *string* como parâmetro e for necessário fazer uma consulta ao *dataframe* usando o *query* para selecionar linhas do *dataframe*. Para isso é necessário o uso de @, observe:

# %%
# função em que o usuário escolhe uma mesorregião e ela retorna o dataframe só com essa mesorregião
# note que essa função apenas usa o query do pandas, mas é para exemplificar o uso de parâmetros
# perceba o uso do @ dentro do query, pois o parâmetro 'meso' é uma string
def mostra(meso):
    meso_escolhida = imrs.query('nome_meso == @meso').reset_index().drop('index', axis=1)
    return meso_escolhida

# %%
# uso da função 'mostra'
mostra('Sul/Sudoeste de Minas')
# Out:
#        ibge7  meso              nome_meso  micro                nome_micro  \
# 0    3101201  3110  Sul/Sudoeste de Minas  31055               Andrelândia
# 1    3101300  3110  Sul/Sudoeste de Minas  31054              São Lourenço
# 2    3101409  3110  Sul/Sudoeste de Minas  31051           Poços de Caldas
# 131               Senador Amaral                0.00               0.00
# 132           Senador José Bento                0.00               0.00
# 133                    Seritinga                0.00               0.00
# 134                     Serrania               53.22               0.00
# 135                     Serranos                0.00               0.00
# 136                Silvianópolis                0.00               0.00
# 137            Soledade de Minas                0.00               0.00
# 138                Tocos do Moji                0.00               0.00
# 139                       Toledo              223.05               0.00
# 140                Três Corações               41.71              19.83
# 141                  Três Pontas               29.26               7.03
# 142                  Turvolândia              170.94               0.00
# 143                     Varginha               43.40               6.10
# 144                     Virgínia               48.73               0.00
# 145               Wenceslau Braz                0.00               0.00
#
#      tx_mort_mama  tx_mort_inf     ...         rdpc  renocup  perc_rdpc_140  \
# 0            0.00        16.95     ...       539.92   734.85          11.70
# 1            0.00         0.00     ...       413.75   558.92          17.57
# 2            0.00         0.00     ...       564.08   796.26           3.02
# 3           10.61        13.46     ...       783.41  1229.94           5.53
# 4           22.23        21.74     ...       633.91  1029.25           8.46
# 5            0.00         0.00     ...       475.99   703.77          12.40
# 6           21.52         2.21     ...       754.39  1020.58           2.51
# 7           16.37         0.00     ...       534.68   795.97          14.75
# 8           71.02         0.00     ...       411.16   675.75          18.11
# 9           21.76         0.00     ...       576.68   900.41           2.94
# 10          29.39         4.83     ...       622.83   919.90           5.64
# 11          32.85         4.78     ...       497.21   788.46          15.28
# 12           0.00         0.00     ...       554.52   829.38           3.98
# 13          25.98        14.93     ...       599.17   903.37           8.43
# 14           0.00        88.24     ...       501.73   691.47           8.99
# 15           0.00         0.00     ...       464.99   668.24          15.48
# 16           0.00        28.57     ...       607.73   910.68           5.13
# 17          19.95         0.00     ...       447.85   695.69          18.46
# 18          47.35         9.26     ...       635.37   972.68           6.20
# 19           0.00         6.49     ...       630.12   981.16           6.41
# 20          13.84        11.36     ...       613.88   743.27          12.16
# 21          19.11        11.11     ...       491.08   617.29          11.87
# 22           0.00        11.43     ...       571.60   875.64           9.08
# 23           0.00         9.43     ...       527.44   731.24          11.66
# 24           0.00         0.00     ...       627.21   838.08           7.58
# 25           9.78        19.05     ...       649.49  1193.90           7.90
# 26          30.18         9.17     ...       712.90   966.41           4.57
# 27           0.00        20.41     ...       588.83   816.35          11.54
# 28          13.03         6.21     ...       686.16  1021.62           6.55
# 29           0.00        17.17     ...       669.87   971.33           7.91
# ..            ...          ...     ...          ...      ...            ...
# 116          0.00         0.00     ...       458.65   760.59           9.59
# 117          0.00         6.01     ...       648.31   979.10           9.82
# 118         30.04         0.00     ...       676.07  1090.47           5.50
# 119          0.00         0.00     ...       538.08   825.82           8.41
# 120          0.00         0.00     ...       714.22  1195.19           6.67
# 121          0.00         0.00     ...       537.13   682.76          10.85
# 122          9.13         5.81     ...       831.32  1166.57           5.89
# 123          0.00        23.26     ...       549.49   714.47           9.80
# 124          0.00        29.85     ...       573.43   924.33           6.35
# 125          9.15        13.79     ...       775.73  1173.64           4.09
# 126          0.00         0.00     ...       442.98   710.65          12.18
# 127         28.29        32.26     ...       593.38   843.39           5.94
# 128          0.00        37.74     ...       428.33   648.83          13.48
# 129         27.67        20.20     ...       527.55   831.29          19.83
# 130         32.93        24.10     ...       497.65   799.69           9.34
# 126      143         26.5        134.17   8234.70      27.83      35.93
# 127      467         25.2        148.35  14779.62      57.77      21.47
# 128      415         44.0        239.46   8559.06      23.58      25.52
# 129      559         26.2        143.66  10975.30      29.55      37.80
# 130      522         28.4        161.40   7654.90      19.68      35.22
# 131      498         11.2         62.22  10945.91      69.54      17.13
# 132       99         16.9        112.74  11580.37      45.36      24.48
# 133       80         22.0        129.52   8858.99      33.56      36.75
# 134      505         23.9        122.48  14943.55      48.91      25.29
# 135      194         17.5        118.78   8647.97      40.86      34.31
# 136      348         25.3        132.88  12107.30      43.11      25.54
# 137      309         16.7         89.10   6847.11      26.29      34.58
# 138      215          8.9         53.36   6413.10      65.90      13.41
# 139      378         14.5         81.77   5804.02      50.35      20.57
# 140     3963         33.8        257.27  24161.24      12.02      42.41
# 141     2868         30.0        180.56  13712.40      31.21      34.37
# 142      434         24.1        122.26  14923.95      55.00      20.31
# 143     1746         42.8        344.56  32144.45       5.94      46.41
# 144      961         11.3         51.67   9622.79      43.00      27.31
# 145      184         16.3        106.36   6894.89      24.92     100.00
#
#      tx_ativ_18m
# 0          68.45
# 1          64.49
# 2          74.53
# 3          68.37
# 4          66.19
# 5          65.32
# 6          74.06
# 7          59.99
# 8          50.79
# 9          67.74
# 10         67.08
# 11         62.21
# 12         74.54
# 13         64.92
# 14         68.46
# 15         58.69
# 16         70.00
# 17         69.35
# 18         65.06
# 19         69.11
# 20         64.58
# 21         70.55
# 22         71.64
# 23         64.57
# 24         67.55
# 25         71.56
# 26         69.83
# 27         68.34
# 28         70.14
# 29         73.02
# ..           ...
# 116        77.10
# 117        65.79
# 118        67.26
# 119        64.23
# 120        63.72
# 121        67.45
# 122        65.32
# 123        71.83
# 124        67.22
# 125        69.11
# 126        54.93
# 127        69.01
# 128        77.57
# 129        64.12
# 130        65.28
# 131        69.40
# 132        69.07
# 133        67.83
# 134        63.96
# 135        54.32
# 136        67.83
# 137        65.69
# 138        75.58
# 139        71.26
# 140        69.23
# 141        71.75
# 142        75.28
# 143        70.37
# 144        59.06
# 145        53.46
#
# [146 rows x 42 columns]

# %% [markdown]
# ## Sugestões para o trabalho
# - não vale usar os códigos e funções que passei como exemplo e simplesmente mudar para outra variável ou município, novos códigos devem ser pensados
# - escolher mesorregiões de MG
# - usar mais de uma variável na mesma função
# - retornar maior e menor valor de alguma variável
# - retornar outras medidas estatísticas em funções
# - calcular porcentagens (de homens, mulheres)
# - função que recebe uma variável e uma cidade e retorna seu valor
# - função que recebe uma cidade e retorna todos os indicadores
# - função que recebe uma mesorregião e uma variável e retorna a média dessa variável para a mesorregião

# %% [markdown]
# ### Importante:
#
# - não é necessário que o trabalho seja em torno de um tema (demografia, saúde etc.), as funções e códigos podem misturar assuntos sem problema algum (funções que retornam informações de renda, outras funções que retornem informações sobre saúde etc.). Mas quem quiser trabalhar com um tema fique à vontade
# - gráficos podem ser utilizados para ilustrar resultados (basta correr atrás da documentação de pacotes do *Python*, como *seaborn*, *matplotlib* etc. ou o site *stackoverflow*)
# - o importante é utilizar o que vimos na disciplina, evitando usar funções prontas do *Python* e tentando criar seus próprios códigos
